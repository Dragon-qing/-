# %%
import pandas as pd

# %%
stock_data = pd.read_csv("./data/stock_day.csv")

# %%
stock_data.head()
# Out:
#              open   high  close    low    volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48  23331.04          0.44      2.05
#
#                ma5    ma10    ma20     v_ma5    v_ma10    v_ma20  turnover
# 2018-02-27  22.942  22.142  22.875  53782.64  46738.65  55576.11      2.39
# 2018-02-26  22.406  21.955  22.942  40827.52  42736.34  56007.50      1.53
# 2018-02-23  21.938  21.929  23.022  35119.58  41871.97  56372.85      1.32
# 2018-02-22  21.446  21.909  23.137  35397.58  39904.78  60149.60      0.90
# 2018-02-14  21.366  21.923  23.253  33590.21  42935.74  61716.11      0.58

# %%
stock_data.drop(["ma5", "ma10", "ma20", "v_ma5",
                "v_ma10", "v_ma20", "turnover"], axis=1)
# Out:
#              open   high  close    low     volume  price_change  p_change
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48   23331.04          0.44      2.05
# ...           ...    ...    ...    ...        ...           ...       ...
# 2015-03-06  13.17  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05  12.88  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04  12.80  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03  12.52  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02  12.25  12.67  12.52  12.20   96291.73          0.32      2.62
#
# [643 rows x 7 columns]

# %% [markdown]
# # pandas索引

# %%
stock_data["open"]['2018-02-27']
# Out:
# 23.53

# %%
stock_data.loc["2018-02-27":"2018-02-23", "close"]
# Out:
# 2018-02-27    24.16
# 2018-02-26    23.53
# 2018-02-23    22.82
# Name: close, dtype: float64

# %%
stock_data.iloc[:3, :5]
# Out:
#              open   high  close    low    volume
# 2018-02-27  23.53  25.88  24.16  23.53  95578.03
# 2018-02-26  22.80  23.78  23.53  22.80  60985.11
# 2018-02-23  22.88  23.37  22.82  22.71  52914.01

# %%
stock_data.columns.get_indexer(["open", "close"])
# Out:
# array([0, 2], dtype=int64)

# %% [markdown]
# # 赋值

# %%
stock_data.open = 100

# %%
stock_data
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26   100  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22   100  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14   100  21.99  21.92  21.48   23331.04          0.44      2.05
# ...          ...    ...    ...    ...        ...           ...       ...
# 2015-03-06   100  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05   100  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04   100  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03   100  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02   100  12.67  12.52  12.20   96291.73          0.32      2.62
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20  turnover
# ...

# %%
stock_data["open"] = 1

# %%
stock_data.head()
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27     1  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26     1  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23     1  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22     1  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14     1  21.99  21.92  21.48  23331.04          0.44      2.05
#
#                ma5    ma10    ma20     v_ma5    v_ma10    v_ma20  turnover
# 2018-02-27  22.942  22.142  22.875  53782.64  46738.65  55576.11      2.39
# 2018-02-26  22.406  21.955  22.942  40827.52  42736.34  56007.50      1.53
# 2018-02-23  21.938  21.929  23.022  35119.58  41871.97  56372.85      1.32
# 2018-02-22  21.446  21.909  23.137  35397.58  39904.78  60149.60      0.90
# 2018-02-14  21.366  21.923  23.253  33590.21  42935.74  61716.11      0.58

# %%
stock_data.sort_values(by = "high", ascending=False).head()
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2015-06-10     1  36.35  33.85  32.23  269033.12          0.51      1.53
# 2015-06-12     1  35.98  35.21  34.01  159825.88          0.82      2.38
# 2017-10-31     1  35.22  34.44  32.20  361660.88          2.38      7.42
# 2015-06-15     1  34.99  31.69  31.69  199369.53         -3.52    -10.00
# 2015-06-11     1  34.98  34.39  32.51  173075.73          0.54      1.59
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20  turnover
# 2015-06-10  30.538  28.660  27.424  176305.53  152266.76  149078.50      9.21
# 2015-06-12  33.420  30.513  28.683  197248.25  154480.41  153888.00      5.47
# 2017-10-31  32.350  30.077  28.406  372824.04  334531.90  241075.48      9.05
# 2015-06-15  33.696  30.964  29.114  201148.55  164608.26  158362.17      6.82
# 2015-06-11  32.016  29.572  28.036  193141.45  151337.71  151428.57      5.92

# %%
stock_data.sort_index().head()
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2015-03-02     1  12.67  12.52  12.20   96291.73          0.32      2.62
# 2015-03-03     1  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-04     1  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-05     1  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-06     1  14.48  14.28  13.13  179831.72          1.12      8.51
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20  turnover
# 2015-03-02  12.520  12.520  12.520   96291.73   96291.73   96291.73      3.30
# 2015-03-03  12.610  12.610  12.610  117681.67  117681.67  117681.67      4.76
# 2015-03-04  12.707  12.707  12.707  100812.93  100812.93  100812.93      2.30
# 2015-03-05  12.820  12.820  12.820   98904.79   98904.79   98904.79      3.19
# 2015-03-06  13.112  13.112  13.112  115090.18  115090.18  115090.18      6.16
