# %%
import matplotlib.pyplot as plt
import random

# %%
x = range(60)
y_wuhan = [random.uniform(10,20) for i in x]
y_shanghai = [random.uniform(20,30) for i in x]

# %%
# plt.figure(figsize = (20, 8), dpi = 100)
# plt.rcParams["font.sans-serif"] = ["Microsoft YaHei"]
# plt.plot(x, y_wuhan, label = "武汉", color = "r", linestyle = "-.")
# plt.plot(x, y_shanghai, label = "上海", color = "b")
# plt.xlabel("时间")
# plt.ylabel("温度")
# plt.title("一小时温度变化", fontsize = 20)
# x_ticks = ["12点{}分".format(i) for i in x]
# y_ticks = range(40)
# plt.xticks(x[::5], x_ticks[::5])
# plt.yticks(y_ticks[::5])
# plt.grid(True, linestyle = "--", alpha = 0.7)
# plt.legend()
# plt.show()

fig, axes = plt.subplots(nrows = 1, ncols= 2, figsize = (20, 8), dpi = 100)
axes[0].plot(x, y_wuhan, label = "武汉", color = "g", linestyle = "--")
axes[1].plot(x, y_shanghai, label = "上海", color = "b")
axes[0].legend()
axes[1].legend()
plt.show()

# %% [markdown]
# # plot绘制数学图像

# %%
import numpy as np

# %%
x = np.linspace(-10, 10, 1000)
y = x**3
plt . figure(figsize = (20, 8), dpi = 100)
plt.plot(x, y)
plt.grid()
plt.show()
