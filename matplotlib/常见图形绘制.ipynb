# %%
import matplotlib.pyplot as plt

# %%
x = [225.98, 247.07, 253.14, 457.85, 241.58, 301.01,  20.67, 288.64,
       163.56, 120.06, 207.83, 342.75, 147.9 ,  53.06, 224.72,  29.51,
        21.61, 483.21, 245.25, 399.25, 343.35]
y = [196.63, 203.88, 210.75, 372.74, 202.41, 247.61,  24.9 , 239.34,
       140.32, 104.15, 176.84, 288.23, 128.79,  49.64, 191.74,  33.1 ,
        30.74, 400.02, 205.35, 330.64, 283.45]

# %%
plt.figure(figsize=(20, 8), dpi=100)
plt.scatter(x, y)
plt.show()

# %%
plt.figure(figsize=(20, 8),dpi = 100)
movie_name = ['雷神3：诸神黄昏','正义联盟','东方快车谋杀案','寻梦环游记','全球风暴', '降魔传','追捕','七十七天','密战','狂兽','其它']
box_office = [73853,57767,22354,15969,14839,8725,8716,8318,7916,6764,52222]
x = range(len(movie_name))
plt.xticks(x, movie_name)
plt.grid(linestyle="--", alpha=0.5)
plt.title("电影票房收入对比")
plt.bar(x, box_office, width=0.5, color=['b','r','g','y','c','m','y','k','c','g','b'])
plt.rcParams["font.sans-serif"] = ["Microsoft YaHei"]
plt.show()

# %%
plt.figure(figsize=(20,8),dpi = 100)

person_height = [165,167,168,169,170,190,188,155]
plt.hist(person_height,bins=5, density=True)
plt.show()

# %%
plt.figure(figsize=(20, 8),dpi = 100)
number = [6,20,30,44,90]
explode = [0,0,0,0.1,0]
number_name = ["class1","class2","class3","class4","class5"]
plt.pie(number, labels=number_name,autopct="%1.2f%%", explode = explode)
plt.show()
